# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Datasets/autodata.csv')

# %%
df.sample(5)
# Out:
#      Unnamed: 0  symboling  normalized-losses        make aspiration  \
# 185         185          3                122  volkswagen        std
# 145         145          0                 85      subaru      turbo
# 21           21          1                118       dodge        std
# 162         162          1                168      toyota        std
# 84           84          1                125  mitsubishi      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 185          two  convertible          fwd           front        94.5  ...
# 145         four        wagon          4wd           front        96.9  ...
# 21           two    hatchback          fwd           front        93.7  ...
# 162          two    hatchback          rwd           front        94.5  ...
# 84          four        sedan          fwd           front        96.3  ...
#
#      compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
print("---Information--\n")
df.info()
# Out:
# ---Information--
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         201 non-null    int64
#  1   symboling          201 non-null    int64
#  2   normalized-losses  201 non-null    int64
#  3   make               201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
# ...

# %%
print("-----Describe the Dataframe-----")
df.describe()
# Out:
# -----Describe the Dataframe-----
#        Unnamed: 0   symboling  normalized-losses  wheel-base      length  \
# count  201.000000  201.000000          201.00000  201.000000  201.000000
# mean   100.000000    0.840796          122.00000   98.797015    0.837102
# std     58.167861    1.254802           31.99625    6.066366    0.059213
# min      0.000000   -2.000000           65.00000   86.600000    0.678039
# 25%     50.000000    0.000000          101.00000   94.500000    0.801538
# 50%    100.000000    1.000000          122.00000   97.000000    0.832292
# 75%    150.000000    2.000000          137.00000  102.400000    0.881788
# max    200.000000    3.000000          256.00000  120.900000    1.000000
#
#             width      height  curb-weight  engine-size        bore  \
# count  201.000000  201.000000   201.000000   201.000000  201.000000
# mean     0.915126   53.766667  2555.666667   126.875622    3.330692
# std      0.029187    2.447822   517.296727    41.546834    0.268072
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
df['stroke'].fillna(method='ffill', inplace=True)
df['horsepower'].fillna(method='ffill', inplace=True)
df['peak-rpm'].fillna(method='ffill', inplace=True)
df['horsepower-binned'].fillna(method='ffill', inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %%
print("===Data Standardization====\n")


#Converting miles per galon to liters per 100km

print("-----Standardizing 'city-mpg' column to 'city-L/100km'-----")
df["city-L/100km"] = 235/df["city-mpg"]
df.head()
# Out:
# ===Data Standardization====
#
# -----Standardizing 'city-mpg' column to 'city-L/100km'-----
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
# ...

# %%
print("======Data Normalization====\n")
print("-------Normalizing 'length', 'width', 'height' column----\n")

df['length']=df['length']/df['length'].max()
df['width']=df['width']/df['width'].max()
df['height']=df['height']/df['height'].max()
print(df[['length','width','height']].head())
# Out:
# ======Data Normalization====
#
# -------Normalizing 'length', 'width', 'height' column----
#
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %%
print("-------turning categorical values into quantitative (numeric) variables---------")
# Out:
# -------turning categorical values into quantitative (numeric) variables---------

# %%
df['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df['aspiration'].replace('std', 0, inplace=True)
df['aspiration'].replace('turbo', 1, inplace=True)

# %%
df.sample(10)
# Out:
#      Unnamed: 0  symboling  normalized-losses        make  aspiration  \
# 94           94          1                103      nissan           0
# 157         157          0                 91      toyota           0
# 108         108          0                161      peugot           0
# 79           79          3                122  mitsubishi           1
# 192         192         -2                103       volvo           0
# 55           55          3                150       mazda           0
# 170         170         -1                 65      toyota           1
# 76           76          1                161  mitsubishi           1
# 44           44          0                145      jaguar           0
# 190         190         -2                103       volvo           0
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 94          four      wagon          fwd           front        94.5  ...
# ...
